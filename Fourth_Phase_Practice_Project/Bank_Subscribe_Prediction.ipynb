# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("termdeposit_train.csv")

# %%
df.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# ...

# %%
df.describe()
# Out:
#                  ID           age        balance           day      duration  \
# count  31647.000000  31647.000000   31647.000000  31647.000000  31647.000000
# mean   22563.972162     40.957247    1363.890258     15.835466    258.113534
# std    13075.936990     10.625134    3028.304293      8.337097    257.118973
# min        2.000000     18.000000   -8019.000000      1.000000      0.000000
# 25%    11218.000000     33.000000      73.000000      8.000000    104.000000
# 50%    22519.000000     39.000000     450.000000     16.000000    180.000000
# 75%    33879.500000     48.000000    1431.000000     21.000000    318.500000
# max    45211.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  31647.000000  31647.000000  31647.000000
# mean       2.765697     39.576042      0.574272
# std        3.113830     99.317592      2.422529
# min        1.000000     -1.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
df.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='marital',data=df)
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %%
plt.figure(figsize=(10,20))
sns.catplot(x="subscribed",col="marital",data=df,kind="count")

# %%
plt.figure(figsize=(10,20))
sns.catplot(x="subscribed",col="education",data=df,kind="count")

# %%
plt.figure(figsize=(50,20))
sns.catplot(x="subscribed",col="job",data=df,kind="count")

# %%
plt.figure(figsize=(20,10))
sns.pairplot(data=df,hue="subscribed",palette="Dark2")
plt.show()

# %%
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df.drop(['ID','job'],axis=1,inplace=True)

# %%
df['marital'].unique()
# Out:
# array(['married', 'divorced', 'single'], dtype=object)

# %%
df['marital']=df['marital'].replace({'single':0,'divorced':0,'married':1})

# %%
df['education'].unique()
# Out:
# array(['unknown', 'secondary', 'tertiary', 'primary'], dtype=object)

# %%
df['education']=df['education'].replace({'unknown':0,'primary':0,'secondary':2,'tertiary':1})

# %%
df['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['default']=df['default'].replace({'no':0,'yes':1})

# %%
df['housing'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['housing']=df['housing'].replace({'no':0,'yes':1})

# %%
df['loan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['loan']=df['loan'].replace({'no':1,'yes':0})

# %%
plt.figure(figsize=(10,20))
sns.catplot(x="subscribed",col="loan",data=df,kind="count")

# %%
df.drop(['contact','day','month','poutcome'],axis=1,inplace=True)

# %%
df['subscribed']=df['subscribed'].replace({'yes':1,'no':0})

# %%
df
# Out:
#        age  marital  education  default  balance  housing  loan  duration  \
# 0       56        1          0        0     1933        0     1        44
# 1       31        1          2        0        3        0     1        91
# 2       27        1          2        0      891        1     1       240
# 3       57        0          1        0     3287        0     1       867
# 4       31        1          2        0      119        1     1       380
# ...    ...      ...        ...      ...      ...      ...   ...       ...
# 31642   29        0          1        0        0        1     1       116
# 31643   53        0          1        0      380        0     0       438
# 31644   32        0          1        0      312        0     1        37
# 31645   57        1          2        0      225        1     1        22
# 31646   55        0          2        0      204        1     1      1973
#
#        campaign  pdays  previous  subscribed
# ...

# %%
df.isnull().sum()
# Out:
# age           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# duration      0
# campaign      0
# pdays         0
# previous      0
# subscribed    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         31647 non-null  int64
#  1   marital     31647 non-null  int64
#  2   education   31647 non-null  int64
#  3   default     31647 non-null  int64
#  4   balance     31647 non-null  int64
#  5   housing     31647 non-null  int64
#  6   loan        31647 non-null  int64
#  7   duration    31647 non-null  int64
#  8   campaign    31647 non-null  int64
#  9   pdays       31647 non-null  int64
#  10  previous    31647 non-null  int64
#  11  subscribed  31647 non-null  int64
# dtypes: int64(12)
# memory usage: 2.9 MB

# %%
plt.title("Comparision between subscribed and married educated")
sns.scatterplot(x='balance',y='age',hue="subscribed",data=df)
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor="white")
plotnumber=1
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(6,2,plotnumber)
        sns.distplot(df[col],color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
X=df.drop('subscribed',axis=1)
Y=df['subscribed']

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=df.corr(),annot=True,fmt='0.3f',linecolor="black",linewidths=0.1)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
x
# Out:
#             age   marital  education   default   balance   housing      loan  \
# 0      1.415793  0.810768  -1.697151 -0.137234  0.187933 -1.118201  0.439893
# 1     -0.937156  0.810768   0.875832 -0.137234 -0.449397 -1.118201  0.439893
# 2     -1.313627  0.810768   0.875832 -0.137234 -0.156159  0.894294  0.439893
# 3      1.509911 -1.233398  -0.410659 -0.137234  0.635055 -1.118201  0.439893
# 4     -0.937156  0.810768   0.875832 -0.137234 -0.411091  0.894294  0.439893
# ...         ...       ...        ...       ...       ...       ...       ...
# 31642 -1.125392 -1.233398  -0.410659 -0.137234 -0.450388  0.894294  0.439893
# 31643  1.133439 -1.233398  -0.410659 -0.137234 -0.324903 -1.118201 -2.273280
# 31644 -0.843038 -1.233398  -0.410659 -0.137234 -0.347358 -1.118201  0.439893
# 31645  1.509911  0.810768   0.875832 -0.137234 -0.376088  0.894294  0.439893
# 31646  1.321675 -1.233398   0.875832 -0.137234 -0.383022  0.894294  0.439893
#
# ...

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import cross_val_score

# %%
def evalution(model,X,Y):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=101)
    model.fit(X_train,Y_train)
    pred=model.predict(X_test)
    acc=(accuracy_score(Y_test,pred))*100
    class_report=classification_report(Y_test,pred)
    cross_val=(cross_val_score(model,X,Y,cv=5).mean())*100
    result=acc-cross_val
    print('Accuracy :',acc)
    print('Classification report :\n',
          class_report)
    print("Cross validation score  :",cross_val)
    print('Accuracy-Cross_validation  :',result)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
evalution(model,x,Y)
# Out:
# Accuracy : 89.24697209057399
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      8390
#            1       0.62      0.19      0.30      1105
#
#     accuracy                           0.89      9495
#    macro avg       0.76      0.59      0.62      9495
# weighted avg       0.87      0.89      0.87      9495
#
# Cross validation score  : 88.94364989565074
# Accuracy-Cross_validation  : 0.3033221949232541

# %%
from sklearn.svm import SVC

# %%
model=SVC()
evalution(model,x,Y)
# Out:
# Accuracy : 89.29963138493943
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8390
#            1       0.66      0.17      0.27      1105
#
#     accuracy                           0.89      9495
#    macro avg       0.78      0.58      0.61      9495
# weighted avg       0.87      0.89      0.86      9495
#
# Cross validation score  : 89.19958754518245
# Accuracy-Cross_validation  : 0.10004383975697806

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 85.50816219062665
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      8390
#            1       0.39      0.41      0.40      1105
#
#     accuracy                           0.86      9495
#    macro avg       0.65      0.66      0.66      9495
# weighted avg       0.86      0.86      0.86      9495
#
# Cross validation score  : 85.45519021870041
# Accuracy-Cross_validation  : 0.05297197192624026

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 89.6893101632438
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      8390
#            1       0.60      0.34      0.44      1105
#
#     accuracy                           0.90      9495
#    macro avg       0.76      0.66      0.69      9495
# weighted avg       0.88      0.90      0.88      9495
#
# Cross validation score  : 89.34179060404762
# Accuracy-Cross_validation  : 0.3475195591961864

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model=ExtraTreesClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 89.07846234860453
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      8390
#            1       0.56      0.29      0.38      1105
#
#     accuracy                           0.89      9495
#    macro avg       0.74      0.63      0.66      9495
# weighted avg       0.87      0.89      0.88      9495
#
# Cross validation score  : 88.73194255885231
# Accuracy-Cross_validation  : 0.34651978975222164

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 88.44655081621906
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      8390
#            1       0.51      0.28      0.36      1105
#
#     accuracy                           0.88      9495
#    macro avg       0.71      0.62      0.65      9495
# weighted avg       0.86      0.88      0.87      9495
#
# Cross validation score  : 88.43807673846186
# Accuracy-Cross_validation  : 0.008474077757199439

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier

# %%
model=GradientBoostingClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 90.01579778830964
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      8390
#            1       0.63      0.33      0.44      1105
#
#     accuracy                           0.90      9495
#    macro avg       0.78      0.65      0.69      9495
# weighted avg       0.88      0.90      0.89      9495
#
# Cross validation score  : 89.6672460104282
# Accuracy-Cross_validation  : 0.34855177788143976

# %%
model=BaggingClassifier()
evalution(model,x,Y)
# Out:
# Accuracy : 88.76250658241179
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      8390
#            1       0.53      0.32      0.40      1105
#
#     accuracy                           0.89      9495
#    macro avg       0.72      0.64      0.67      9495
# weighted avg       0.87      0.89      0.88      9495
#
# Cross validation score  : 88.68770276095617
# Accuracy-Cross_validation  : 0.07480382145561748

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'criterion':['gini','entropy'],
        'max_depth':[2,3,4],
        'max_leaf_nodes':[2,3,4],
       'min_samples_split':[0.1,0.5,0.8],
       'min_samples_leaf':[0.5,0.1,0.8],
       'bootstrap':[True,False],
       'oob_score':[True,False]}

# %%
rfc=RandomForestClassifier()
grid=GridSearchCV(rfc,param_grid=params)

# %%
 X_train,X_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.3,random_state=101)

# %%
grid.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4], 'max_leaf_nodes': [2, 3, 4],
#                          'min_samples_leaf': [0.5, 0.1, 0.8],
#                          'min_samples_split': [0.1, 0.5, 0.8],
#                          'oob_score': [True, False]})

# %%
grid.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_leaf_nodes': 2,
#  'min_samples_leaf': 0.5,
#  'min_samples_split': 0.1,
#  'oob_score': True}

# %%
final_model=RandomForestClassifier(bootstrap=True,
 criterion='gini',
 max_depth=2,
 max_leaf_nodes=2,
 min_samples_leaf=0.5,
 min_samples_split=0.1,
 oob_score=True)

# %%
final_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_depth=2, max_leaf_nodes=2, min_samples_leaf=0.5,
#                        min_samples_split=0.1, oob_score=True)

# %%
pred=final_model.predict(X_test)

# %%
acc=accuracy_score(Y_test,pred)
print(acc)
# Out:
# 0.8836229594523434

# %%
from sklearn.metrics import roc_curve,auc,RocCurveDisplay
fpr,tpr,threshold=roc_curve(Y_test,pred)
roc_auc=auc(fpr,tpr)
display=RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %%
import joblib
joblib.dump(final_model,'Bank_Market_Prediction.pkl')
# Out:
# ['Bank_Market_Prediction.pkl']

# %%
df1=pd.read_csv('termdeposit_test.csv')

# %%
df1
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df1.drop(['ID','job','contact','poutcome'],axis=1,inplace=True)

# %%
df1['marital']=df1['marital'].replace({'single':0,'divorced':0,'married':1})

# %%
df1['education']=df1['education'].replace({'unknown':0,'primary':0,'secondary':2,'tertiary':1})

# %%
df1['housing']=df1['housing'].replace({'no':0,'yes':1})

# %%
df1['loan']=df1['loan'].replace({'no':1,'yes':0})

# %%
df1['default']=df1['default'].replace({'no':0,'yes':1})

# %%
df1
# Out:
#        age  marital  education  default  balance  housing  loan  duration  \
# 0       32        1          0        0      118        0     1        20
# 1       78        1          2        0     2787        0     1       372
# 2       31        1          2        0      144        1     1       676
# 3       57        0          1        0     3777        0     1        65
# 4       45        1          2        0     -705        1     1       111
# ...    ...      ...        ...      ...      ...      ...   ...       ...
# 13559   39        0          2        0       45        1     0       148
# 13560   54        1          2        0     2281        1     1       158
# 13561   35        1          0        0      285        0     1       136
# 13562   29        1          2        0      464        1     1       208
# 13563   29        1          2        0        2        1     1       339
#
#        campaign  pdays  previous
# 0             6     -1         0
# ...

# %%
model=joblib.load("Bank_Market_Prediction.pkl")

# %%
prediction=model.predict(df1)

# %%
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df2=pd.DataFrame()
df2['Predicted']=prediction
df2
# Out:
#        Predicted
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 13559          0
# 13560          0
# 13561          0
# 13562          0
# 13563          0
#
# [13564 rows x 1 columns]
