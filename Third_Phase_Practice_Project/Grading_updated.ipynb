# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Grades.csv')

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
df.drop('Seat No.',axis=1,inplace=True)

# %%
df['PH-121'].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
df['HS-101'].unique()
# Out:
# array(['D+', 'D', 'B', 'C+', 'A-', 'B-', 'C-', 'B+', 'C', 'A', 'A+', 'F'],
#       dtype=object)

# %%
df['PH-121']=df['PH-121'].replace({'F':0,'WU':1,'D':2,'D+':3,'C-':4,'C':5,'C+':6,'B-':7,'B':8,'B+':9,'A-':10,'A':11,'A+':12})

# %%
df['PH-121'].unique()
# Out:
# array([ 7, 11,  2, 10,  9,  8,  6,  5,  4,  3,  1, 12,  0], dtype=int64)

# %%
df['HS-101']=df['HS-101'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CY-105'].unique()
# Out:
# array(['C-', 'D+', 'A', 'A-', 'B', 'C+', 'B+', 'B-', 'C', 'D', nan, 'WU',
#        'A+', 'F'], dtype=object)

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df['CY-105'].unique()
# Out:
# array(['C-', 'D+', 'A', 'A-', 'B', 'C+', 'B+', 'B-', 'C', 'D', 'A+'],
#       dtype=object)

# %%
df['CY-105']=df['CY-105'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['HS-105/12'].unique()
# Out:
# array(['C', 'D', 'B-', 'B+', 'D+', 'B', 'C-', 'C+', 'A-', 'A', 'A+'],
#       dtype=object)

# %%
df['HS-105/12']=df['HS-105/12'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['MT-111'].unique()
# Out:
# array(['C-', 'B-', 'B+', 'D', 'A', 'C+', 'A-', 'C', 'B', 'D+', 'A+'],
#       dtype=object)

# %%
df['MT-111']=df['MT-111'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-105'].unique()
# Out:
# array(['D+', 'C', 'A', 'A-', 'B', 'B-', 'B+', 'C+', 'C-', 'A+', 'D'],
#       dtype=object)

# %%
df['CS-105']=df['CS-105'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-106'].unique()
# Out:
# array(['D', 'B-', 'D+', 'A-', 'C+', 'A', 'C-', 'C', 'B', 'B+', 'A+'],
#       dtype=object)

# %%
df['CS-106']=df['CS-106'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EL-102'].unique()
# Out:
# array(['C-', 'A', 'B+', 'B', 'A-', 'B-', 'C', 'C+', 'D+', 'D', 'A+'],
#       dtype=object)

# %%
df['EL-102']=df['EL-102'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EE-119'].unique()
# Out:
# array(['B-', 'D+', 'A-', 'D', 'A', 'B+', 'B', 'C-', 'C+', 'C', 'A+'],
#       dtype=object)

# %%
df['EE-119']=df['EE-119'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['ME-107'].unique()
# Out:
# array(['C-', 'D', 'A-', 'C+', 'B+', 'A', 'D+', 'C', 'B', 'B-', 'A+'],
#       dtype=object)

# %%
df['ME-107']=df['ME-107'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-107'].unique()
# Out:
# array(['C-', 'B+', 'B-', 'D', 'C', 'A-', 'C+', 'D+', 'B', 'A', 'A+'],
#       dtype=object)

# %%
df['CS-107']=df['CS-107'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['HS-205/20'].unique()
# Out:
# array(['B+', 'C+', 'A-', 'B', 'A', 'B-', 'D', 'A+', 'C', 'D+', 'C-'],
#       dtype=object)

# %%
df['HS-205/20']=df['HS-205/20'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['MT-222'].unique()
# Out:
# array(['D', 'B-', 'A', 'D+', 'C', 'B+', 'A-', 'B', 'C+', 'C-', 'A+'],
#       dtype=object)

# %%
df['MT-222']=df['MT-222'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EE-222'].unique()
# Out:
# array(['A-', 'C-', 'A', 'B-', 'B+', 'C+', 'D+', 'B', 'C', 'A+', 'D', 'F'],
#       dtype=object)

# %%
df['EE-222']=df['EE-222'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-210'].unique()
# Out:
# array(['C+', 'D+', 'A', 'C', 'A-', 'B+', 'B-', 'B', 'D', 'A+', 'C-', 'F'],
#       dtype=object)

# %%
df['CS-210']=df['CS-210'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-211'].unique()
# Out:
# array(['D+', 'D', 'A+', 'B+', 'B-', 'B', 'A-', 'C-', 'C+', 'C', 'A'],
#       dtype=object)

# %%
df['CS-211']=df['CS-211'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-203'].unique()
# Out:
# array(['D+', 'C', 'A', 'C+', 'A-', 'B+', 'B', 'B-', 'C-', 'D', 'A+'],
#       dtype=object)

# %%
df['CS-203']=df['CS-203'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-214'].unique()
# Out:
# array(['D', 'A-', 'B', 'C', 'B-', 'C+', 'A', 'C-', 'B+', 'D+', 'A+'],
#       dtype=object)

# %%
df['CS-214']=df['CS-214'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EE-217'].unique()
# Out:
# array(['A', 'B-', 'D+', 'A-', 'A+', 'C', 'B+', 'B', 'C-', 'D', 'C+'],
#       dtype=object)

# %%
df['EE-217']=df['EE-217'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-212'].unique()
# Out:
# array(['D', 'C', 'A-', 'C+', 'B-', 'D+', 'B+', 'B', 'A', 'C-', 'A+'],
#       dtype=object)

# %%
df['CS-212']=df['CS-212'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-215'].unique()
# Out:
# array(['C-', 'D', 'A', 'A-', 'C+', 'C', 'B+', 'B-', 'D+', 'B', 'A+'],
#       dtype=object)

# %%
df['CS-215']=df['CS-215'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['MT-331'].unique()
# Out:
# array(['C', 'D+', 'A', 'C+', 'B+', 'A-', 'B', 'B-', 'A+', 'D', 'C-'],
#       dtype=object)

# %%
df['MT-331']=df['MT-331'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EF-303'].unique()
# Out:
# array(['C-', 'D', 'C+', 'B+', 'C', 'D+', 'A-', 'B-', 'A', 'B', 'WU', 'F'],
#       dtype=object)

# %%
df['MT-331']=df['MT-331'].replace({'F':0,'WU':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10})

# %%
df['HS-304'].unique()
# Out:
# array(['C+', 'C-', 'A', 'B-', 'A-', 'B+', 'B', 'C', 'D', 'D+', 'F', 'W'],
#       dtype=object)

# %%
df['HS-304']=df['HS-304'].replace({'F':0,'W':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10})

# %%
df['CS-301'].unique()
# Out:
# array(['B', 'A-', 'B+', 'D', 'B-', 'D+', 'C', 'C+', 'C-', 'A', 'A+'],
#       dtype=object)

# %%
df['CS-301']=df['CS-301'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-302'].unique()
# Out:
# array(['C', 'D+', 'A-', 'B-', 'C+', 'B', 'D', 'B+', 'A', 'C-', 'A+'],
#       dtype=object)

# %%
df['CS-302']=df['CS-302'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['TC-383'].unique()
# Out:
# array(['C+', 'C-', 'B', 'D+', 'C', 'B+', 'B-', 'D', 'A-', 'A', 'A+'],
#       dtype=object)

# %%
df['TC-383']=df['TC-383'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['MT-442'].unique()
# Out:
# array(['B+', 'C-', 'A', 'A-', 'B', 'A+', 'C+', 'B-', 'D+', 'D', 'C'],
#       dtype=object)

# %%
df['MT-442']=df['MT-442'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['EL-332'].unique()
# Out:
# array(['C', 'B+', 'D+', 'A-', 'B', 'A', 'B-', 'C-', 'C+', 'D', 'A+', 'F',
#        'WU'], dtype=object)

# %%
df['EL-332']=df['EL-332'].replace({'F':0,'WU':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-318'].unique()
# Out:
# array(['C-', 'A-', 'B+', 'B-', 'C', 'B', 'C+', 'D', 'D+', 'A', 'A+', 'WU',
#        'F'], dtype=object)

# %%
df['CS-318']=df['CS-318'].replace({'F':0,'WU':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-306'].unique()
# Out:
# array(['C', 'D', 'A-', 'C-', 'B+', 'C+', 'B-', 'B', 'A', 'D+', 'A+', 'F'],
#       dtype=object)

# %%
df['CS-306']=df['CS-306'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-312'].unique()
# Out:
# array(['C-', 'D+', 'B', 'B-', 'C', 'B+', 'C+', 'A-', 'D', 'A', 'A+', 'F'],
#       dtype=object)

# %%
df['CS-312']=df['CS-312'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-317'].unique()
# Out:
# array(['C-', 'D', 'B', 'C', 'B+', 'B-', 'A-', 'D+', 'C+', 'A', 'A+', 'F'],
#       dtype=object)

# %%
df['CS-317']=df['CS-317'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-403'].unique()
# Out:
# array(['C-', 'C', 'A', 'D+', 'B+', 'C+', 'B-', 'A-', 'B', 'A+', 'D'],
#       dtype=object)

# %%
df['CS-403']=df['CS-403'].replace({'D':0,'D+':1,'C-':2,'C':3,'C+':4,'B-':5,'B':6,'B+':7,'A-':8,'A':9,'A+':10})

# %%
df['CS-421'].unique()
# Out:
# array(['C-', 'D', 'C', 'B-', 'C+', 'B+', 'D+', 'B', 'A', 'A-', 'A+', 'F',
#        'W'], dtype=object)

# %%
df['CS-421']=df['CS-421'].replace({'F':0,'W':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-406'].unique()
# Out:
# array(['A-', 'A', 'B-', 'B', 'B+', 'C+', 'D', 'D+', 'A+', 'C', 'F', 'W',
#        'C-'], dtype=object)

# %%
df['CS-406']=df['CS-406'].replace({'F':0,'W':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-414'].unique()
# Out:
# array(['A', 'B-', 'B', 'A-', 'B+', 'A+', 'C', 'C-', 'C+', 'F', 'D', 'D+'],
#       dtype=object)

# %%
df['CS-414']=df['CS-414'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-419'].unique()
# Out:
# array(['C-', 'C', 'A', 'C+', 'A-', 'B+', 'B-', 'B', 'D+', 'A+', 'D', 'F'],
#       dtype=object)

# %%
df['CS-419']=df['CS-419'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-423'].unique()
# Out:
# array(['B', 'C', 'A-', 'C+', 'B-', 'B+', 'C-', 'A', 'D+', 'D', 'A+', 'F'],
#       dtype=object)

# %%
df['CS-423']=df['CS-423'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['CS-412'].unique()
# Out:
# array(['A-', 'B', 'A', 'C+', 'B+', 'C-', 'B-', 'A+', 'C', 'W', 'D', 'D+',
#        'F'], dtype=object)

# %%
df['CS-412']=df['CS-412'].replace({'F':0,'W':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         7       2       2          3       2       1       0       2
# 1        11       1       1          0       5       3       0       9
# 2        11       7       9          5       7       9       5       7
# 3         2       5       1          0       0       8       1       2
# 4        10       9       8          7       9       9       8       7
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       8      10       9          8      10       9       8       8
# 567      12      10       9          9       9       9       9       8
# 568       8      10       8          7       9       9       9       9
# 569      11       8       0          9       0       1       5       2
# 570       5       1       0          3       3       1       6       4
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421 CS-406  CS-414  \
# ...

# %%
df['MT-224'].unique()
# Out:
# array(['B-', 'D+', 'A', 'D', 'A-', 'C-', 'C', 'B+', 'C+', 'B', 'A+', 'F'],
#       dtype=object)

# %%
df['MT-224']=df['MT-224'].replace({'F':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10,'A+':11})

# %%
df['EF-303'].unique()
# Out:
# array(['C-', 'D', 'C+', 'B+', 'C', 'D+', 'A-', 'B-', 'A', 'B', 'WU', 'F'],
#       dtype=object)

# %%
df['EF-303']=df['EF-303'].replace({'F':0,'WU':0,'D':1,'D+':2,'C-':3,'C':4,'C+':5,'B-':6,'B':7,'B+':8,'A-':9,'A':10})

# %%
df['EL-332'].unique()
# Out:
# array([ 4,  8,  2,  9,  7, 10,  6,  3,  5,  1, 11,  0], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     417 non-null    int64
#  1   HS-101     417 non-null    int64
#  2   CY-105     417 non-null    int64
#  3   HS-105/12  417 non-null    int64
#  4   MT-111     417 non-null    int64
#  5   CS-105     417 non-null    int64
#  6   CS-106     417 non-null    int64
#  7   EL-102     417 non-null    int64
#  8   EE-119     417 non-null    int64
#  9   ME-107     417 non-null    int64
#  10  CS-107     417 non-null    int64
#  11  HS-205/20  417 non-null    int64
#  12  MT-222     417 non-null    int64
#  13  EE-222     417 non-null    int64
#  14  MT-224     417 non-null    int64
#  15  CS-210     417 non-null    int64
#  16  CS-211     417 non-null    int64
#  17  CS-203     417 non-null    int64
#  18  CS-214     417 non-null    int64
#  19  EE-217     417 non-null    int64
# ...

# %%
plt.figure(figsize=(10,20))
plotnumber=1
for col in df:
    if plotnumber<=42:
       ax=plt.subplot(21,2,plotnumber)
       sns.distplot(df[col],color='m')
       plt.xlabel(col)
       plt.yticks()
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(50,40))
sns.heatmap(data=df.corr(),annot=True,fmt='0.3f',linecolor="black",linewidths=0.1)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
X=df.drop('CGPA',axis=1)
Y=df['CGPA']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
x
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0   -0.846140 -1.453193 -2.301301  -0.960167 -1.385083 -3.338314 -2.070949
# 1    0.868759 -1.828181 -2.733378  -1.932773 -0.306839 -2.343973 -2.070949
# 2    0.868759  0.421750  0.723236  -0.311763  0.411991  0.639049 -0.228829
# 3   -2.989764 -0.328227 -2.733378  -1.932773 -2.103913  0.141878 -1.702525
# 4    0.440034  1.171727  0.291160   0.336641  1.130821  0.639049  0.876443
# ..        ...       ...       ...        ...       ...       ...       ...
# 412 -0.417415  1.546715  0.723236   0.660844  1.490236  0.639049  0.876443
# 413  1.297484  1.546715  0.723236   0.985046  1.130821  0.639049  1.244867
# 414 -0.417415  1.546715  0.291160   0.336641  1.130821  0.639049  1.244867
# 415  0.868759  0.796738 -3.165455   0.985046 -2.103913 -3.338314 -0.228829
# 416 -1.703590 -1.828181 -3.165455  -0.960167 -1.025668 -3.338314  0.139595
#
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
maxAccu=0
maxRS=0
for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best R2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best R2 score is 0.9980796918060292 on Random State 949

# %%
from sklearn.model_selection import cross_val_score

# %%
def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=949)
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    rmse = mean_squared_error(Y_test, pred,squared=False)
    print("RMSE Score is:", rmse)
    r2 = r2_score(Y_test, pred)*100
    print("R2 Score is:", r2)
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
model=LinearRegression()
reg(model,x,Y)
# Out:
# RMSE Score is: 0.02596198591664546
# R2 Score is: 99.80796918060292
# Cross Validation Score: 99.59795411245189
# R2 Score - Cross Validation Score is 0.2100150681510371

# %%
from sklearn.linear_model import Ridge

# %%
model=Ridge()
reg(model,x,Y)
# Out:
# RMSE Score is: 0.025926460747279712
# R2 Score is: 99.80849435306091
# Cross Validation Score: 99.59938968639563
# R2 Score - Cross Validation Score is 0.20910466666528293

# %%
from sklearn.linear_model import Lasso

# %%
model=Lasso()
reg(model,x,Y)
# Out:
# RMSE Score is: 0.6023331370458291
# R2 Score is: -3.363838230474503
# Cross Validation Score: -0.9765866354289354
# R2 Score - Cross Validation Score is -2.3872515950455675

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
model=RandomForestRegressor(max_depth=2)
reg(model,x,Y)
# Out:
# RMSE Score is: 0.20665643195118238
# R2 Score is: 87.83273495499398
# Cross Validation Score: 81.47704477086835
# R2 Score - Cross Validation Score is 6.355690184125635

# %%
model=KNeighborsRegressor(n_neighbors=2)
reg(model,x,Y)
# Out:
# RMSE Score is: 0.10826548058229035
# R2 Score is: 96.66054857151845
# Cross Validation Score: 95.36507862026242
# R2 Score - Cross Validation Score is 1.295469951256024

# %%
model=GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
reg(model, x, Y)
# Out:
# RMSE Score is: 0.19588212022333354
# R2 Score is: 89.06837544754207
# Cross Validation Score: 86.7735168961837
# R2 Score - Cross Validation Score is 2.2948585513583737

# %%
model=AdaBoostRegressor(n_estimators=300, learning_rate=1.05)
reg(model, x, Y)
# Out:
# RMSE Score is: 0.15062965149374616
# R2 Score is: 93.53578105591605
# Cross Validation Score: 92.02314961406962
# R2 Score - Cross Validation Score is 1.5126314418464233

# %%
model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
reg(model, x, Y)
# Out:
# RMSE Score is: 0.0832075260146346
# R2 Score is: 98.0274849115317
# Cross Validation Score: 96.96520487072866
# R2 Score - Cross Validation Score is 1.0622800408030457

# %%
model=XGBRegressor()
reg(model,x, Y)
# Out:
# RMSE Score is: 0.11957126291222822
# R2 Score is: 95.92667795489677
# Cross Validation Score: 91.96851397913744
# R2 Score - Cross Validation Score is 3.9581639757593337

# %%
from sklearn.model_selection import GridSearchCV

# %%
base=Ridge()
params={'alpha':np.arange(0.001,0.1,0.001)}
grid_model=GridSearchCV(base,param_grid=params,scoring='neg_mean_squared_error',cv=5,verbose=2)

# %%
grid_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.002; total time=   0.0s
# [CV] END ........................................alpha=0.002; total time=   0.0s
# [CV] END ........................................alpha=0.002; total time=   0.0s
# [CV] END ........................................alpha=0.002; total time=   0.0s
# [CV] END ........................................alpha=0.002; total time=   0.0s
# [CV] END ........................................alpha=0.003; total time=   0.0s
# ...

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.099}

# %%
final_model=Ridge(alpha=0.099)

# %%
final_model.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.099)

# %%
pred=final_model.predict(X_test)

# %%
rmse = mean_squared_error(Y_test, pred)
print("RMSE Score is:", rmse)
r2 = r2_score(Y_test, pred)*100
print("R2 Score is:", r2)
cv_score = (cross_val_score(model, x, Y, cv=5).mean())*100
print("Cross Validation Score:", cv_score)
result = r2 - cv_score
print("R2 Score - Cross Validation Score is", result)
# Out:
# RMSE Score is: 0.0012218120642935218
# R2 Score is: 99.66133425213076
# Cross Validation Score: 91.96851397913744
# R2 Score - Cross Validation Score is 7.692820272993316

# %%
import joblib
joblib.dump(final_model,'Grading.pkl')
# Out:
# ['Grading.pkl']

# %%
model=joblib.load("Grading.pkl")
prediction=model.predict(X_test)
prediction
# Out:
# array([2.92711811, 2.56846365, 3.79226808, 2.58292403, 3.36507959,
#        3.29402358, 3.27691759, 3.80265992, 3.12460634, 3.21745402,
#        3.5753451 , 2.958     , 3.4968417 , 4.04777238, 3.41790319,
#        2.72290174, 2.1938425 , 3.67233926, 2.9771639 , 3.02275207,
#        3.24296945, 3.49745832, 2.8917723 , 1.71097011, 3.12069245,
#        2.61502252, 2.90423192, 3.03466327, 1.92078957, 3.38355619,
#        2.3040901 , 3.79288924, 2.13174568, 3.81384856, 2.91309992,
#        3.86871114, 3.02259777, 3.43981904, 3.75946151, 3.37516188,
#        3.68475443, 3.6762397 , 1.91625748, 3.38981352, 3.43617282,
#        3.31540481, 3.06232423, 2.03270424, 3.56949921, 2.5912468 ,
#        3.96869944, 3.54960232, 2.80059586, 2.44594838, 3.02127533,
#        3.25784135, 2.59973866, 3.7379651 , 3.68829047, 3.32520768,
#        3.55803027, 2.97795478, 3.71642841, 3.18629158, 2.69592886,
#        3.35601264, 3.32435659, 3.18779632, 2.96076858, 2.38090905,
# ...

# %%
a=np.array(Y_test)
df1=pd.DataFrame()
df1['Predicted']=prediction
df1['Actual']=a
df1
# Out:
#      Predicted  Actual
# 0     2.927118   2.928
# 1     2.568464   2.608
# 2     3.792268   3.751
# 3     2.582924   2.566
# 4     3.365080   3.424
# ..         ...     ...
# 100   2.663426   2.619
# 101   3.102254   3.112
# 102   2.943736   2.999
# 103   3.658568   3.672
# 104   1.978953   1.996
#
# [105 rows x 2 columns]
